# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = "/home/sauer_julian/code/lukasst00-code/climate_trace_emission_tool/raw_data/power/electricity-generation_emissions_sources_v5_8_0.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    source_id        source_name source_type iso3_country sector  \
# 0   25452484  RECIP power plant         oil          ABW  power
# 1   25452484  RECIP power plant         oil          ABW  power
# 2   25452484  RECIP power plant         oil          ABW  power
# 3   25452484  RECIP power plant         oil          ABW  power
# 4   25452484  RECIP power plant         oil          ABW  power
#
#                 subsector           start_time             end_time      lat  \
# 0  electricity-generation  2021-01-01 00:00:00  2021-01-31 00:00:00  12.4759
# 1  electricity-generation  2021-02-01 00:00:00  2021-02-28 00:00:00  12.4759
# 2  electricity-generation  2021-03-01 00:00:00  2021-03-31 00:00:00  12.4759
# 3  electricity-generation  2021-04-01 00:00:00  2021-04-30 00:00:00  12.4759
# 4  electricity-generation  2021-05-01 00:00:00  2021-05-31 00:00:00  12.4759
#
#        lon  ...  other7                                   other7_def  other8  \
# ...

# %%
df.columns
# Out:
# Index(['source_id', 'source_name', 'source_type', 'iso3_country', 'sector',
#        'subsector', 'start_time', 'end_time', 'lat', 'lon', 'geometry_ref',
#        'gas', 'emissions_quantity', 'temporal_granularity', 'activity',
#        'activity_units', 'emissions_factor', 'emissions_factor_units',
#        'capacity', 'capacity_units', 'capacity_factor', 'other1', 'other1_def',
#        'other2', 'other2_def', 'other3', 'other3_def', 'other4', 'other4_def',
#        'other5', 'other5_def', 'other6', 'other6_def', 'other7', 'other7_def',
#        'other8', 'other8_def', 'other9', 'other9_def', 'other10',
#        'other10_def', 'created_date', 'modified_date'],
#       dtype='object')

# %%
(df['activity'] == 0).sum()
# Out:
# np.int64(64394)

# %%
df.shape
# Out:
# (742784, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2432428 entries, 0 to 2432427
# Data columns (total 10 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   source_id                         float64
#  1   source_name                       object
#  2   iso3_country                      object
#  3   original_inventory_sector         object
#  4   strategy_id                       int64
#  5   strategy_name                     object
#  6   total_emissions_reduced_per_year  float64
#  7   gas                               object
#  8   strategy_description              object
#  9   difficulty_score                  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 185.6+ MB

# %%
df["iso3_country"].unique()
# Out:
# array(['CHN', 'HKG', 'NOR', 'ISL', 'BRA', 'JPN', 'MUS', 'COD', 'USA',
#        'COL', 'CMR', 'TWN', 'TUR', 'CHL', 'AUS', 'VNM', 'ITA', 'MEX',
#        'MYS', 'EGY', 'BGD', 'SWE', 'MLT', 'PAK', 'ARE', 'ISR', 'IDN',
#        'PER', 'JAM', 'IRN', 'DZA', 'HND', 'PAN', 'GEO', 'DJI', 'LBN',
#        'PRK', 'MAR', 'RUS', 'CRI', 'SXM', 'SEN', 'TCA', 'MOZ', 'CUW',
#        'PHL', 'IND', 'CUB', 'GTM', 'GNQ', 'CAN', 'GRC', 'ALB', 'VEN',
#        'ECU', 'MNE', 'TUN', 'QAT', 'BGR', 'AZE', 'YEM', 'LBY', 'GBR',
#        'BLZ', 'SLV', 'DNK', 'DOM', 'SAU', 'NIC', 'THA', 'EST', 'ESH',
#        'HRV', 'NLD', 'SGP', 'TZA', 'MYT', 'MDV', 'HTI', 'VIR', 'GLP',
#        'FIN', 'MMR', 'KNA', 'ESP', 'VUT', 'NGA', 'BHS', 'NAM', 'DEU',
#        'LKA', 'BEL', 'AUT', 'SRB', 'GIN', 'TKM', 'PNG', 'PLW', 'KAZ',
#        'KWT', 'AGO', 'ROU', 'NZL', 'IRL', 'GNB', 'CPV', 'SGS', 'FRA',
#        'MRT', 'SVK', 'OMN', 'FRO', 'BEN', 'PRI', 'ZAF', 'GAB', 'KOR',
# ...

# %%
df["original_inventory_sector"].unique()
# Out:
# array(['solid-waste-disposal', 'aluminum', 'domestic-shipping',
#        'international-shipping', 'cropland-fires',
#        'electricity-generation', 'other-chemicals',
#        'manure-applied-to-soils', 'rice-cultivation',
#        'synthetic-fertilizer-application', 'textiles-leather-apparel',
#        'manure-management-cattle-operation',
#        'enteric-fermentation-cattle-pasture', 'road-transportation',
#        'manure-left-on-pasture-cattle', 'water-reservoirs',
#        'enteric-fermentation-cattle-operation',
#        'domestic-wastewater-treatment-and-discharge',
#        'oil-and-gas-production', 'residential-onsite-fuel-usage',
#        'forest-land-fires', 'oil-and-gas-refining', 'coal-mining',
#        'non-residential-onsite-fuel-usage', 'food-beverage-tobacco',
#        'crop-residues', 'glass', 'other-metals', 'other-manufacturing',
#        'chemicals', 'petrochemical-steam-cracking',
#        'industrial-wastewater-treatment-and-discharge', 'iron-mining',
# ...
